# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\SHIN Soyeon\Desktop\DSL\volume_investors.csv", encoding='cp949')
data['Date'] = pd.to_datetime(data['Date'])
data['Month'] = [x.month for x in data['Date']]
data['Year'] = [x.year for x in data['Date']]
data['Day'] = [x.day for x in data['Date']]

data
# Out:
#            Date  Institution  Individual   Foreign  Total  Month  Year  Day
# 0    1999-01-04    -461684.0     78101.0  383584.0    0.0      1  1999    4
# 1    1999-01-05      21212.0    -82190.0   60978.0    0.0      1  1999    5
# 2    1999-01-06     -18162.0    -11325.0   29487.0    0.0      1  1999    6
# 3    1999-01-07     -37797.0   -167771.0  205568.0    0.0      1  1999    7
# 4    1999-01-08      54683.0   -130880.0   76197.0    0.0      1  1999    8
# ...         ...          ...         ...       ...    ...    ...   ...  ...
# 5922 2022-12-23     236988.0   -161628.0  -85824.0    0.0     12  2022   23
# 5923 2022-12-26     649924.0   -588342.0  -57875.0    0.0     12  2022   26
# 5924 2022-12-27     986200.0  -1110497.0   73000.0    0.0     12  2022   27
# 5925 2022-12-28    -851720.0   1060858.0 -264263.0    0.0     12  2022   28
# 5926 2022-12-29    -612363.0    664928.0 -102228.0    0.0     12  2022   29
#
# [5927 rows x 8 columns]

# %%
data[data['Month']==12].groupby('Day')['Individual'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
data[data['Month']==12].groupby('Day')['Institution'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
rec = data[(data["Date"]>="2015-12-01")&(data["Date"]<="2022-12-29")]
rec[rec['Month']==12].groupby('Day')['Individual'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
rec[rec['Month']==12].groupby('Day')['Institution'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
decf = rec[(rec["Day"]>=1)&(rec["Day"]<=15)]
decf[decf['Month']==12].groupby('Day')['Individual'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
decs = rec[(rec["Day"]>=16)&(rec["Day"]<=31)]
decs[decs['Month']==12].groupby('Day')['Individual'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
decf = rec[(rec["Day"]>=1)&(rec["Day"]<=15)]
decf[decf['Month']==12].groupby('Day')['Institution'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
decs = rec[(rec["Day"]>=16)&(rec["Day"]<=31)]
decs[decs['Month']==12].groupby('Day')['Institution'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
temp = []
for x in rec['Day']:
  if x < 10:
    temp.append(1)
  elif x < 20:
    temp.append(2)
  else: 
    temp.append(3)
rec['Month_third'] = temp
rec
# Out:
# C:\Users\SHIN Soyeon\AppData\Local\Temp\ipykernel_28684\3707779209.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['Month_third'] = temp
#            Date  Institution  Individual   Foreign  Total  Month  Year  Day  \
# 4185 2015-12-01      88376.0   -244235.0   99681.0    0.0     12  2015    1
# 4186 2015-12-02     -22943.0    136106.0 -288174.0    0.0     12  2015    2
# 4187 2015-12-03    -149668.0    266004.0 -245722.0    0.0     12  2015    3
# 4188 2015-12-04       7742.0    209877.0 -357830.0    0.0     12  2015    4
# 4189 2015-12-07     -73817.0    102051.0 -148663.0    0.0     12  2015    7
# ...         ...          ...         ...       ...    ...    ...   ...  ...
# ...

# %%
a = rec[rec['Month']==12][rec['Month_third']==1].groupby('Day')['Individual'].mean().plot(kind='bar')
# Out:
# C:\Users\SHIN Soyeon\AppData\Local\Temp\ipykernel_28684\2494215977.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a = rec[rec['Month']==12][rec['Month_third']==1].groupby('Day')['Individual'].mean().plot(kind='bar')

# %%
b = rec[rec['Month']==12][rec['Month_third']==2].groupby('Day')['Individual'].mean().plot(kind='bar')
# Out:
# C:\Users\SHIN Soyeon\AppData\Local\Temp\ipykernel_28684\4079642859.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   b = rec[rec['Month']==12][rec['Month_third']==2].groupby('Day')['Individual'].mean().plot(kind='bar')

# %%
c = rec[rec['Month']==12][rec['Month_third']==3].groupby('Day')['Individual'].mean().plot(kind='bar')
# Out:
# C:\Users\SHIN Soyeon\AppData\Local\Temp\ipykernel_28684\1461354834.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   c = rec[rec['Month']==12][rec['Month_third']==3].groupby('Day')['Individual'].mean().plot(kind='bar')

# %%
a = rec[rec['Month']==12][rec['Month_third']==1].groupby('Day')['Institution'].mean().plot(kind='bar')
# Out:
# C:\Users\SHIN Soyeon\AppData\Local\Temp\ipykernel_28684\3601488730.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a = rec[rec['Month']==12][rec['Month_third']==1].groupby('Day')['Institution'].mean().plot(kind='bar')

# %%
b = rec[rec['Month']==12][rec['Month_third']==2].groupby('Day')['Institution'].mean().plot(kind='bar')
# Out:
# C:\Users\SHIN Soyeon\AppData\Local\Temp\ipykernel_28684\3311314236.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   b = rec[rec['Month']==12][rec['Month_third']==2].groupby('Day')['Institution'].mean().plot(kind='bar')
