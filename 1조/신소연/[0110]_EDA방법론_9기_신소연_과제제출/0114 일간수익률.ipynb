# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

kospi_df = pd.read_csv(r"C:\Users\SHIN Soyeon\Desktop\EDA Project\Dataset\kospi_data.csv")
kospi_df
# Out:
#              Date    Close     Open     High      Low       Volume  Change
# 0      1981-05-01   123.60   123.60   123.60   123.60    3330000.0  0.0098
# 1      1981-05-02   123.50   123.50   123.50   123.50    2040000.0 -0.0008
# 2      1981-05-04   120.60   120.60   120.60   120.60    1930000.0 -0.0235
# 3      1981-05-06   120.70   120.70   120.70   120.70    1690000.0  0.0008
# 4      1981-05-07   119.30   119.30   119.30   119.30    1480000.0 -0.0116
# ...           ...      ...      ...      ...      ...          ...     ...
# 11019  2022-08-25  2477.26  2459.79  2477.26  2455.32  426230000.0  0.0122
# 11020  2022-08-26  2481.03  2489.14  2497.76  2476.75  520090000.0  0.0015
# 11021  2022-08-29  2426.89  2432.06  2432.89  2417.01  448750000.0 -0.0218
# 11022  2022-08-30  2450.93  2441.21  2453.91  2433.48     327210.0  0.0099
# 11023  2022-08-31  2472.05  2433.47  2473.75  2426.14     397290.0  0.0086
#
# [11024 rows x 7 columns]

# %%
from datetime import datetime
kospi_df["Date"] = pd.to_datetime(kospi_df["Date"])

# %% [markdown]
# 대한민국 20대 대통령

# %%
pdt20 = kospi_df[(kospi_df["Date"]>="2022-03-01")&(kospi_df["Date"]<="2022-08-31")]
close = pdt20['Close']
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])

# %%
pdt20_1 = pd.DataFrame(a, index=pdt20["Date"][1:], columns=['Close'])
pdt20_1
# Out:
#             Close
# Date
# 2022-03-03  43.56
# 2022-03-04 -33.65
# 2022-03-07 -62.12
# 2022-03-08 -28.91
# 2022-03-10  57.92
# ...           ...
# 2022-08-25  29.81
# 2022-08-26   3.77
# 2022-08-29 -54.14
# 2022-08-30  24.04
# 2022-08-31  21.12
#
# [125 rows x 1 columns]

# %%
pdt20_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 63 62 상승세-하락세 : 1

# %% [markdown]
# 대한민국 19대 대통령

# %%
#상반기

pdt19f = kospi_df[(kospi_df["Date"]>="2017-05-01")&(kospi_df["Date"]<="2020-03-01")]
close = pdt19f["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt19f_1 = pd.DataFrame(a, index=pdt19f["Date"][1:], columns=['Close'])
pdt19f_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 368 322 상승세-하락세 : 46

# %%
#하반기

pdt19s = kospi_df[(kospi_df["Date"]>="2020-03-01")&(kospi_df["Date"]<="2022-03-01")]
close = pdt19s["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt19s_1 = pd.DataFrame(a, index=pdt19s["Date"][1:], columns=['Close'])
pdt19s_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 278 215 상승세-하락세 : 63

# %% [markdown]
# 대한민국 18대 대통령

# %%
pdt18f = kospi_df[(kospi_df["Date"]>="2012-12-01")&(kospi_df["Date"]<="2015-12-01")]
close = pdt18f["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt18f_1 = pd.DataFrame(a, index=pdt18f["Date"][1:], columns=['Close'])
pdt18f_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 376 362 상승세-하락세 : 14

# %%
pdt18s = kospi_df[(kospi_df["Date"]>="2015-12-01")&(kospi_df["Date"]<="2017-05-01")]
close = pdt18s["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt18s_1 = pd.DataFrame(a, index=pdt18s["Date"][1:], columns=['Close'])
pdt18s_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 185 163 상승세-하락세 : 22

# %% [markdown]
# 대한민국 17대 대통령

# %%
pdt17f = kospi_df[(kospi_df["Date"]>="2007-12-01")&(kospi_df["Date"]<="2010-12-01")]
close = pdt17f["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt17f_1 = pd.DataFrame(a, index=pdt17f["Date"][1:], columns=['Close'])
pdt17f_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 399 349 상승세-하락세 : 50

# %%
pdt17s = kospi_df[(kospi_df["Date"]>="2010-12-01")&(kospi_df["Date"]<="2012-12-01")]
close = pdt17s["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt17s_1 = pd.DataFrame(a, index=pdt17s["Date"][1:], columns=['Close'])
pdt17s_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 250 249 상승세-하락세 : 1

# %% [markdown]
# 대한민국 16대 대통령

# %%
pdt16f = kospi_df[(kospi_df["Date"]>="2002-12-01")&(kospi_df["Date"]<="2005-12-01")]
close = pdt16f["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt16f_1 = pd.DataFrame(a, index=pdt16f["Date"][1:], columns=['Close'])
pdt16f_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 410 333 상승세-하락세 : 77

# %%
pdt16s = kospi_df[(kospi_df["Date"]>="2005-12-01")&(kospi_df["Date"]<="2007-12-01")]
close = pdt16s["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt16s_1 = pd.DataFrame(a, index=pdt16s["Date"][1:], columns=['Close'])
pdt16s_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 291 204 상승세-하락세 : 87

# %% [markdown]
# 대한민국 15대 대통령

# %%
pdt15f = kospi_df[(kospi_df["Date"]>="1997-12-01")&(kospi_df["Date"]<="2000-12-01")]
close = pdt15f["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt15f_1 = pd.DataFrame(a, index=pdt15f["Date"][1:], columns=['Close'])
pdt15f_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 409 378 상승세-하락세 : 31

# %%
pdt15s = kospi_df[(kospi_df["Date"]>="2000-12-01")&(kospi_df["Date"]<="2002-12-01")]
close = pdt15s["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt15s_1 = pd.DataFrame(a, index=pdt15s["Date"][1:], columns=['Close'])
pdt15s_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 263 224 상승세-하락세 : 39

# %% [markdown]
# 대한민국 14대 대통령

# %%
pdt14f = kospi_df[(kospi_df["Date"]>="1992-12-01")&(kospi_df["Date"]<="1995-12-01")]
close = pdt14f["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt14f_1 = pd.DataFrame(a, index=pdt14f["Date"][1:], columns=['Close'])
pdt14f_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 446 439 상승세-하락세 : 7

# %%
pdt14s = kospi_df[(kospi_df["Date"]>="1995-12-01")&(kospi_df["Date"]<="1997-12-01")]
close = pdt14s["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt14s_1 = pd.DataFrame(a, index=pdt14s["Date"][1:], columns=['Close'])
pdt14s_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 263 322 상승세-하락세 : -59

# %% [markdown]
# 대한민국 13대 대통령

# %%
pdt13f = kospi_df[(kospi_df["Date"]>="1987-12-01")&(kospi_df["Date"]<="1990-12-01")]
close = pdt13f["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt13f_1 = pd.DataFrame(a, index=pdt13f["Date"][1:], columns=['Close'])
pdt13f_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 410 463 상승세-하락세 : -53

# %%
pdt13s = kospi_df[(kospi_df["Date"]>="1990-12-01")&(kospi_df["Date"]<="1992-12-01")]
close = pdt13s["Close"]
a = []
for k in close.index[:-1]:
    a.append(close[k+1]-close[k])
pdt13s_1 = pd.DataFrame(a, index=pdt13s["Date"][1:], columns=['Close'])
pdt13s_1.plot.bar()
plt.show()

# %%
up=0
down=0
for i in a:
    if i>=0:
        up+=1
    elif i<=0:
        down+=1

print(up, down, "상승세-하락세 : {}".format(up-down))
# Out:
# 264 321 상승세-하락세 : -57

# %%
#pdt13s['Close_lag'] = pdt13s['Close'].shift(1)
#pdt13s[""]
#pdt13s

#kospi_df[(kospi_df["Date"]>="1990-12-01")&(kospi_df["Date"]<="1992-12-01")]['Change'].plot(kind='bar')
#pdt13s['Change']

# %% [markdown]
# # 통계적 사고 과제: 가설검정

# %%
#상반기 중 종가가 내렸으면 1, 올랐으면 0의 값을 갖는 확률변수

X=[]
for i in pdt13f.index:
    if pdt13f['Change'][i]>0:
        X.append(1)
    elif pdt13f['Change'][i]<0:
        X.append(0)
        
for i in pdt14f.index:
    if pdt14f['Change'][i]>0:
        X.append(1)
    elif pdt14f['Change'][i]<0:
        X.append(0)
        
for i in pdt15f.index:
    if pdt15f['Change'][i]>0:
        X.append(1)
    elif pdt15f['Change'][i]<0:
        X.append(0)
        
for i in pdt16f.index:
    if pdt16f['Change'][i]>0:
        X.append(1)
    elif pdt16f['Change'][i]<0:
        X.append(0)
        
for i in pdt17f.index:
    if pdt17f['Change'][i]>0:
        X.append(1)
    elif pdt17f['Change'][i]<0:
        X.append(0)
        
for i in pdt18f.index:
    if pdt18f['Change'][i]>0:
        X.append(1)
    elif pdt18f['Change'][i]<0:
        X.append(0)

# %%
X_mean = sum(X) / len(X)
X_mean
# Out:
# 0.512610340479193

# %%
from scipy import stats
import seaborn as sns
import scipy as sp

t_stat, p_value = stats.ttest_1samp(X_mean, 0.5)
print("t-statistics : {}, p-value : {}".format(t_stat, p_value))
# Out:
# t-statistics : nan, p-value : nan
# C:\Users\SHIN Soyeon\AppData\Local\Temp\ipykernel_3516\416691643.py:5: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   t_stat, p_value = stats.ttest_1samp(X_mean, 0.5)
# C:\Users\SHIN Soyeon\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:1250: RuntimeWarning: divide by zero encountered in true_divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# C:\Users\SHIN Soyeon\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:1250: RuntimeWarning: invalid value encountered in double_scalars
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero

# %% [markdown]
# numpy 값이 아니라서 오류가 나는 것 같다

# %%
N = 100000
mu_0 = 0
np.random.seed(0)
x = sp.stats.norm(mu_0).rvs(N)
sns.distplot(x, kde=False, fit=sp.stats.norm)
plt.show()

# %%
def ztest_1samp(x, sigma2=1, mu=0):
    z = (x.mean() - mu)/ np.sqrt(sigma2/len(x))
    return z, 2 * sp.stats.norm().sf(np.abs(z))

# %%
ztest_1samp(x)
# Out:
# (0.49859647936208945, 0.6180636858739812)

# %%
X_mean = np.array(X_mean, dtype=np.float64)
type(X_mean)
# Out:
# numpy.ndarray

# %%
ztest_1samp(X_mean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3516\2228062045.py in <module>
# ----> 1 ztest_1samp(X_mean)
#
# ~\AppData\Local\Temp\ipykernel_3516\50460839.py in ztest_1samp(x, sigma2, mu)
#       1 def ztest_1samp(x, sigma2=1, mu=0):
# ----> 2     z = (x.mean() - mu)/ np.sqrt(sigma2/len(x))
#       3     return z, 2 * sp.stats.norm().sf(np.abs(z))
#
# TypeError: len() of unsized object

# %% [markdown]
# numpy 로 바꿨으나 또 문제가 생김 ...

# %% [markdown]
# # (a) 상반기 평균 수익률이 하반기 평균 수익률과 같다

# %% [markdown]
# 귀무가설 : "상반기 평균 수익률이 하반기 평균 수익률과 같다"
#
#
# 대립가설 : "상반기 평균 수익률이 하반기 평균 수익률과 같지 않다"

# %% [markdown]
# 유의수준 : 0.05

# %%
pdt13s = kospi_df[(kospi_df["Date"]>="1990-12-01")&(kospi_df["Date"]<="1992-12-01")]['Change']
A_mean = sum(pdt13s) / len(pdt13s)

pdt13f = kospi_df[(kospi_df["Date"]>="1987-12-01")&(kospi_df["Date"]<="1990-12-01")]['Change']
B_mean = sum(pdt13f) / len(pdt13f)

# %%
def twoSampZ(X1, X2, mudiff, sd1, sd2, n1, n2):
    from numpy import sqrt, abs, round
    from scipy.stats import norm
    pooledSE = sqrt(sd1**2/n1 + sd2**2/n2)
    z = ((X1 - X2) - mudiff)/pooledSE
    pval = 2*(norm.sf(abs(z)))
    return round(z, 3), round(pval, 4)

# %%
a = np.std(pdt13s)
b = np.std(pdt13f)
c = len(pdt13s)
d = len(pdt13f)

# %%
z, p = twoSampZ(A_mean, B_mean, 0, a, b, c, d)
print(z,p)
# Out:
# -0.711 0.4771

# %% [markdown]
# p값이 0.05(유의수준)보다 크기 때문에 귀무가설 채택

# %% [markdown]
# # (b) 상반기 평균 수익률이 음의 값이다

# %%
def ztest_1samp(x, sigma2=1, mu=0):
    z = (x.mean() - mu)/ np.sqrt(sigma2/len(x))
    return z, 2 * sp.stats.norm().sf(np.abs(z))

# %%
ztest_1samp(pdt13s)
# Out:
# (0.0002726434869747842, 0.9997824619738345)
