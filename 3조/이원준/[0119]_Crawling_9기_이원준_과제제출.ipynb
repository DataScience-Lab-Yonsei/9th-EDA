# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

# %%
driver = webdriver.Chrome('chromedriver')

# %%
url = 'https://sbiz.gmr.or.kr/report/trdreport.do'
driver.get(url)

# %%
btn = driver.find_element(By.XPATH, '//*[@id="loginpopup"]/div/div[2]/button[2]')
btn.click()

# %%
user_id = input("ID: ")
user_password = input("PASSWORD: ")

driver.find_element(By.XPATH, '//*[@id="id"]').send_keys(user_id)
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys(user_password)
driver.find_element(By.XPATH, '//*[@id="btn_login"]').click()

# %%
driver.get(url)

# %%
from selenium.webdriver.support.select import Select

# %%
select = Select(driver.find_element(By.XPATH, '//*[@id="selectQuCondition"]'))
select.select_by_index(1)

select = Select(driver.find_element(By.XPATH, '//*[@id="trdar"]'))
select.select_by_index(1)

btn = driver.find_element(By.XPATH, '/html/body/div/section/div/div[2]/div[2]/div/div[3]/button')
btn.click()

# %%
import pandas as pd

# %%
html_source = driver.page_source
soup = BeautifulSoup(html_source, 'html.parser')

# %%
html_table = soup.find('table', 'com_table')
html_table = str(html_table)
df1 = pd.read_html(html_table)[0]

# %%
df1
# Out:
#         행정구역  생활밀접업종 2021년 3분기                  2021년 4분기                   \
#         행정구역  생활밀접업종    전체 점포수 프랜차이즈 점포수 일반 점포수    전체 점포수 프랜차이즈 점포수 일반 점포수
# 0        경기도  전체업종전체     52744      6914  45830     52814      6973  45841
# 1        수원시  전체업종전체      7664      1007   6657      7692      1036   6656
# 2    수원시 장안구  전체업종전체      2246       282   1964      2252       289   1963
# 3    수원시 권선구  전체업종전체      2982       415   2567      2995       423   2572
# 4    수원시 팔달구  전체업종전체      1193       145   1048      1199       151   1048
# 5    수원시 영통구  전체업종전체      1243       165   1078      1246       173   1073
# 6        성남시  전체업종전체      5358       582   4776      5360       578   4782
# 7    성남시 수정구  전체업종전체      1339       129   1210      1329       129   1200
# 8    성남시 중원구  전체업종전체      1818       155   1663      1818       151   1667
# 9    성남시 분당구  전체업종전체      2201       298   1903      2213       298   1915
# ...

# %%
select = Select(driver.find_element(By.XPATH, '//*[@id="selectYear"]'))
select.select_by_index(1)

select = Select(driver.find_element(By.XPATH, '//*[@id="selectQu"]'))
select.select_by_index(2)

btn = driver.find_element(By.XPATH, '/html/body/div/section/div/div[2]/div[2]/div/div[3]/button')
btn.click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

html_table = soup.find('table', 'com_table')
html_table = str(html_table)
df2 = pd.read_html(html_table)[0]
df2
# Out:
#         행정구역  생활밀접업종 2020년 4분기                  2021년 1분기                   \
#         행정구역  생활밀접업종    전체 점포수 프랜차이즈 점포수 일반 점포수    전체 점포수 프랜차이즈 점포수 일반 점포수
# 0        경기도  전체업종전체     51852      6676  45176     52173      6764  45409
# 1        수원시  전체업종전체      7525       953   6572      7572       976   6596
# 2    수원시 장안구  전체업종전체      2258       270   1988      2258       274   1984
# 3    수원시 권선구  전체업종전체      2917       392   2525      2939       402   2537
# 4    수원시 팔달구  전체업종전체      1153       129   1024      1154       135   1019
# 5    수원시 영통구  전체업종전체      1197       162   1035      1221       165   1056
# 6        성남시  전체업종전체      5384       592   4792      5389       592   4797
# 7    성남시 수정구  전체업종전체      1381       132   1249      1371       133   1238
# 8    성남시 중원구  전체업종전체      1818       166   1652      1821       161   1660
# 9    성남시 분당구  전체업종전체      2185       294   1891      2197       298   1899
# ...

# %%
select = Select(driver.find_element(By.XPATH, '//*[@id="selectYear"]'))
select.select_by_index(2)

select = Select(driver.find_element(By.XPATH, '//*[@id="selectQu"]'))
select.select_by_index(1)

btn = driver.find_element(By.XPATH, '/html/body/div/section/div/div[2]/div[2]/div/div[3]/button')
btn.click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

html_table = soup.find('table', 'com_table')
html_table = str(html_table)
df3 = pd.read_html(html_table)[0]
df3
# Out:
#         행정구역  생활밀접업종 2020년 1분기                  2020년 2분기                   \
#         행정구역  생활밀접업종    전체 점포수 프랜차이즈 점포수 일반 점포수    전체 점포수 프랜차이즈 점포수 일반 점포수
# 0        경기도  전체업종전체     50964      6413  44551     51448      6545  44903
# 1        수원시  전체업종전체      7432       924   6508      7485       939   6546
# 2    수원시 장안구  전체업종전체      2224       254   1970      2242       265   1977
# 3    수원시 권선구  전체업종전체      2889       381   2508      2907       381   2526
# 4    수원시 팔달구  전체업종전체      1147       125   1022      1145       122   1023
# 5    수원시 영통구  전체업종전체      1172       164   1008      1191       171   1020
# 6        성남시  전체업종전체      5321       595   4726      5368       590   4778
# 7    성남시 수정구  전체업종전체      1382       134   1248      1384       127   1257
# 8    성남시 중원구  전체업종전체      1810       177   1633      1831       176   1655
# 9    성남시 분당구  전체업종전체      2129       284   1845      2153       287   1866
# ...

# %%
select = Select(driver.find_element(By.XPATH, '//*[@id="selectYear"]'))
select.select_by_index(3)

select = Select(driver.find_element(By.XPATH, '//*[@id="selectQu"]'))
select.select_by_index(0)

btn = driver.find_element(By.XPATH, '/html/body/div/section/div/div[2]/div[2]/div/div[3]/button')
btn.click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

html_table = soup.find('table', 'com_table')
html_table = str(html_table)
df4 = pd.read_html(html_table)[0]
df4
# Out:
#         행정구역  생활밀접업종 2019년 2분기                  2019년 3분기                   \
#         행정구역  생활밀접업종    전체 점포수 프랜차이즈 점포수 일반 점포수    전체 점포수 프랜차이즈 점포수 일반 점포수
# 0        경기도  전체업종전체     49823      6143  43680     50379      6279  44100
# 1        수원시  전체업종전체      7345       906   6439      7357       913   6444
# 2    수원시 장안구  전체업종전체      2210       254   1956      2225       258   1967
# 3    수원시 권선구  전체업종전체      2850       378   2472      2850       379   2471
# 4    수원시 팔달구  전체업종전체      1148       115   1033      1136       117   1019
# 5    수원시 영통구  전체업종전체      1137       159    978      1146       159    987
# 6        성남시  전체업종전체      5289       584   4705      5315       594   4721
# 7    성남시 수정구  전체업종전체      1375       131   1244      1378       134   1244
# 8    성남시 중원구  전체업종전체      1820       172   1648      1831       175   1656
# 9    성남시 분당구  전체업종전체      2094       281   1813      2106       285   1821
# ...

# %%
select = Select(driver.find_element(By.XPATH, '//*[@id="selectYear"]'))
select.select_by_index(3)

select = Select(driver.find_element(By.XPATH, '//*[@id="selectQu"]'))
select.select_by_index(3)

btn = driver.find_element(By.XPATH, '/html/body/div/section/div/div[2]/div[2]/div/div[3]/button')
btn.click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

html_table = soup.find('table', 'com_table')
html_table = str(html_table)
df5 = pd.read_html(html_table)[0]
df5
# Out:
#         행정구역  생활밀접업종 2018년 3분기                  2018년 4분기                   \
#         행정구역  생활밀접업종    전체 점포수 프랜차이즈 점포수 일반 점포수    전체 점포수 프랜차이즈 점포수 일반 점포수
# 0        경기도  전체업종전체     48532      5972  42560     49102      6044  43058
# 1        수원시  전체업종전체      7153       876   6277      7249       892   6357
# 2    수원시 장안구  전체업종전체      2160       244   1916      2187       246   1941
# 3    수원시 권선구  전체업종전체      2768       365   2403      2812       373   2439
# 4    수원시 팔달구  전체업종전체      1143       117   1026      1134       116   1018
# 5    수원시 영통구  전체업종전체      1082       150    932      1116       157    959
# 6        성남시  전체업종전체      5232       564   4668      5251       571   4680
# 7    성남시 수정구  전체업종전체      1371       123   1248      1370       126   1244
# 8    성남시 중원구  전체업종전체      1808       177   1631      1818       176   1642
# 9    성남시 분당구  전체업종전체      2053       264   1789      2063       269   1794
# ...

# %%
df5.drop(['2018년 3분기', '2018년 4분기'], axis = 1, inplace = True)
# Out:
# /var/folders/ld/xyv_k8pj3dl6p3sv6jn1gyz00000gn/T/ipykernel_77185/998281915.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df5.drop(['2018년 3분기', '2018년 4분기'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# MultiIndex([(     '행정구역',      '행정구역'),
#             (   '생활밀접업종',    '생활밀접업종'),
#             ('2021년 3분기',    '전체 점포수'),
#             ('2021년 3분기', '프랜차이즈 점포수'),
#             ('2021년 3분기',    '일반 점포수'),
#             ('2021년 4분기',    '전체 점포수'),
#             ('2021년 4분기', '프랜차이즈 점포수'),
#             ('2021년 4분기',    '일반 점포수'),
#             ('2022년 1분기',    '전체 점포수'),
#             ('2022년 1분기', '프랜차이즈 점포수'),
#             ('2022년 1분기',    '일반 점포수')],
#            )

# %%
df = pd.merge(df5.droplevel(axis = 1, level = 1), df4.droplevel(axis = 1, level = 1), how = 'left', on = ['행정구역', '생활밀접업종'])
df = pd.merge(df, df3.droplevel(axis = 1, level = 1), how = 'left', on = ['행정구역', '생활밀접업종'])
df = pd.merge(df, df2.droplevel(axis = 1, level = 1), how = 'left', on = ['행정구역', '생활밀접업종'])
df = pd.merge(df, df1.droplevel(axis = 1, level = 1), how = 'left', on = ['행정구역', '생활밀접업종'])
df
# Out:
#         행정구역  생활밀접업종  2019년 1분기  2019년 1분기  2019년 1분기  2019년 2분기  2019년 2분기  \
# 0        경기도  전체업종전체      49492       6078      43414      49823       6143
# 1        수원시  전체업종전체       7288        907       6381       7345        906
# 2    수원시 장안구  전체업종전체       2196        255       1941       2210        254
# 3    수원시 권선구  전체업종전체       2821        378       2443       2850        378
# 4    수원시 팔달구  전체업종전체       1147        115       1032       1148        115
# 5    수원시 영통구  전체업종전체       1124        159        965       1137        159
# 6        성남시  전체업종전체       5269        572       4697       5289        584
# 7    성남시 수정구  전체업종전체       1371        129       1242       1375        131
# 8    성남시 중원구  전체업종전체       1814        172       1642       1820        172
# 9    성남시 분당구  전체업종전체       2084        271       1813       2094        281
# 10      의정부시  전체업종전체       1696        184       1512       1696        191
# ...

# %%
df.to_csv(
# Out:
#         행정구역  생활밀접업종 2019년 1분기
#         행정구역  생활밀접업종    전체 점포수 프랜차이즈 점포수 일반 점포수
# 0        경기도  전체업종전체     49492      6078  43414
# 1        수원시  전체업종전체      7288       907   6381
# 2    수원시 장안구  전체업종전체      2196       255   1941
# 3    수원시 권선구  전체업종전체      2821       378   2443
# 4    수원시 팔달구  전체업종전체      1147       115   1032
# 5    수원시 영통구  전체업종전체      1124       159    965
# 6        성남시  전체업종전체      5269       572   4697
# 7    성남시 수정구  전체업종전체      1371       129   1242
# 8    성남시 중원구  전체업종전체      1814       172   1642
# 9    성남시 분당구  전체업종전체      2084       271   1813
# 10      의정부시  전체업종전체      1696       184   1512
# 11       안양시  전체업종전체      2975       328   2647
# 12   안양시 만안구  전체업종전체      1580       167   1413
# 13   안양시 동안구  전체업종전체      1395       161   1234
# 14       부천시  전체업종전체      2847       277   2570
# 15       광명시  전체업종전체       413        39    374
# 16       평택시  전체업종전체      1956       301   1655
# 17      동두천시  전체업종전체       201        18    183
# ...
