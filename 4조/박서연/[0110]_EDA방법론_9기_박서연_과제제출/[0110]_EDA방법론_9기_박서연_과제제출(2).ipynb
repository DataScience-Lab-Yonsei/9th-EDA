# %%
### Calling packages

import numpy as np
import pandas as pd

# %% [markdown]
# ##### **서울시 년도별 평균 대기오염도 정보**

# %%
### '서울시 년도별 평균 대기오염도 정보.csv'를 ATM_yearly_df라는 데이터프레임 형태로 불러오기

ATM_yearly_df = pd.read_csv('C:/Users/izzle/Downloads/서울시 년도별 평균 대기오염도 정보.csv', encoding='cp949')
ATM_yearly_df.head(10)
# Out:
#    측정년도  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  미세먼지(㎍/㎥)  \
# 0  2023   강남구         0.035      0.015           0.7       0.004       61.0
# 1  2023  강남대로         0.039      0.010           0.9       0.004       64.0
# 2  2023   강동구         0.030      0.012           0.7       0.003       66.0
# 3  2023  강변북로         0.042      0.010           0.9       0.003       63.0
# 4  2023   강북구         0.029      0.019           0.7       0.003       66.0
# 5  2023   강서구         0.036      0.016           0.8       0.004       77.0
# 6  2023  공항대로         0.039      0.012           0.7       0.003       67.0
# 7  2023   관악구         0.039      0.013           0.8       0.003       67.0
# 8  2023   관악산         0.013      0.036           0.4       0.004       51.0
# 9  2023   광진구         0.022      0.012           0.9       0.002       61.0
#
#    초미세먼지(㎍/㎥)
# 0        40.0
# 1        44.0
# 2        47.0
# 3        45.0
# 4        37.0
# 5        41.0
# 6        41.0
# ...

# %%
### 데이터 타입

ATM_yearly_df.dtypes
# Out:
# 측정년도              int64
# 측정소명             object
# 이산화질소농도(ppm)    float64
# 오존농도(ppm)       float64
# 일산화탄소농도(ppm)    float64
# 아황산가스(ppm)      float64
# 미세먼지(㎍/㎥)       float64
# 초미세먼지(㎍/㎥)      float64
# dtype: object

# %%
### 데이터의 shape

ATM_yearly_df.shape
# Out:
# (1228, 8)

# %%
### 결측치

ATM_yearly_df.isnull().sum()
# Out:
# 측정년도              0
# 측정소명              0
# 이산화질소농도(ppm)     31
# 오존농도(ppm)        46
# 일산화탄소농도(ppm)     32
# 아황산가스(ppm)       48
# 미세먼지(㎍/㎥)       188
# 초미세먼지(㎍/㎥)      710
# dtype: int64

# %%
### 이산화질소 농도 내림차순 정렬

ATM_yearly_df.sort_values(by='이산화질소농도(ppm)', ascending=False, inplace=False).head()
# Out:
#       측정년도  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 1174  1992  천호대로         0.105      0.014           1.4       0.019
# 1088  1996   신촌로         0.087      0.009           2.2       0.017
# 1096  1996  청계천로         0.084      0.002           2.2       0.018
# 1029  1998   신촌로         0.081      0.008           1.7       0.009
# 1068  1997  청계천로         0.080        NaN           1.7         NaN
#
#       미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 1174        NaN         NaN
# 1088        NaN         NaN
# 1096        NaN         NaN
# 1029        NaN         NaN
# 1068        NaN         NaN

# %%
### 오존 농도 내림차순 정렬

ATM_yearly_df.sort_values(by='오존농도(ppm)', ascending=False, inplace=False).head()
# Out:
#       측정년도    측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 1041  1998     홍릉로         0.063      0.088           1.5       0.006
# 108   2021     관악산         0.009      0.047           0.3       0.003
# 58    2022     관악산         0.009      0.045           0.4       0.003
# 462   2013     관악산         0.018      0.040           NaN       0.006
# 137   2021  자연사박물관         0.020      0.037           0.6       0.004
#
#       미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 1041        NaN         NaN
# 108        34.0        16.0
# 58         29.0        16.0
# 462        34.0        23.0
# 137        36.0        19.0

# %%
### 일산화탄소 농도 내림차순 정렬

ATM_yearly_df.sort_values(by='일산화탄소농도(ppm)', ascending=False, inplace=False).head()
# Out:
#       측정년도  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 1199  1989   구로구         0.034      0.007           5.4       0.091
# 1201  1989   도봉구         0.030      0.008           4.8       0.081
# 1221  1987   도봉구         0.033      0.012           4.6       0.097
# 1202  1989  서대문구         0.033      0.013           4.5       0.105
# 1222  1987  서대문구         0.053      0.014           4.2       0.055
#
#       미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 1199        NaN         NaN
# 1201        NaN         NaN
# 1221        NaN         NaN
# 1202        NaN         NaN
# 1222        NaN         NaN

# %%
### 아황산가스 내림차순 정렬

ATM_yearly_df.sort_values(by='아황산가스(ppm)', ascending=False, inplace=False).head()
# Out:
#       측정년도  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 1212  1988  서대문구         0.029      0.015           4.2       0.121
# 1202  1989  서대문구         0.033      0.013           4.5       0.105
# 1220  1987  구로구2         0.022      0.008           3.2       0.103
# 1211  1988   도봉구         0.030      0.017           4.0       0.097
# 1221  1987   도봉구         0.033      0.012           4.6       0.097
#
#       미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 1212        NaN         NaN
# 1202        NaN         NaN
# 1220        NaN         NaN
# 1211        NaN         NaN
# 1221        NaN         NaN

# %%
### 미세먼지 내림차순 정렬

ATM_yearly_df.sort_values(by='미세먼지(㎍/㎥)', ascending=False, inplace=False).head()
# Out:
#       측정년도  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 793   2005  천호대로         0.011      0.018           0.1       0.029
# 1107  1995  동대문구         0.038      0.012           1.6       0.019
# 1002  1999   중랑구         0.023      0.015           1.5       0.009
# 896   2002    중구         0.030      0.018           1.0       0.005
# 868   2002   강남구         0.039      0.015           0.7       0.005
#
#       미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 793       399.0         NaN
# 1107       97.0         NaN
# 1002       96.0         NaN
# 896        96.0         NaN
# 868        95.0         NaN

# %%
### 초미세먼지 내림차순 정렬

ATM_yearly_df.sort_values(by='초미세먼지(㎍/㎥)', ascending=False, inplace=False).head()
# Out:
#     측정년도 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  미세먼지(㎍/㎥)  \
# 30  2023  신촌로         0.044      0.009           0.9       0.004       73.0
# 41  2023   중구         0.037      0.019           0.7       0.004       63.0
# 2   2023  강동구         0.030      0.012           0.7       0.003       66.0
# 19  2023  마포구         0.038      0.013           0.8       0.004       54.0
# 31  2023  양천구         0.035      0.013           0.8       0.003       71.0
#
#     초미세먼지(㎍/㎥)
# 30        48.0
# 41        47.0
# 2         47.0
# 19        46.0
# 31        46.0

# %% [markdown]
# ##### **서울시 월별 평균 대기오염도 정보**

# %%
### '서울시 월별 평균 대기오염도 정보.csv'를 ATM_monthly_df라는 데이터프레임 형태로 불러오기

ATM_monthly_df = pd.read_csv('C:/Users/izzle/Downloads/서울시 월별 평균 대기오염도 정보.csv', encoding='cp949')
ATM_monthly_df.head(10)
# Out:
#       측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  미세먼지(㎍/㎥)  \
# 0  202301   강남구         0.035      0.015           0.7       0.004       61.0
# 1  202301  강남대로         0.039      0.010           0.9       0.004       64.0
# 2  202301   강동구         0.030      0.012           0.7       0.003       66.0
# 3  202301  강변북로         0.042      0.010           0.9       0.003       63.0
# 4  202301   강북구         0.029      0.019           0.7       0.003       66.0
# 5  202301   강서구         0.036      0.016           0.8       0.004       77.0
# 6  202301  공항대로         0.039      0.012           0.7       0.003       67.0
# 7  202301   관악구         0.039      0.013           0.8       0.003       67.0
# 8  202301   관악산         0.013      0.036           0.4       0.004       51.0
# 9  202301   광진구         0.022      0.012           0.9       0.002       61.0
#
#    초미세먼지(㎍/㎥)
# 0        40.0
# 1        44.0
# 2        47.0
# 3        45.0
# 4        37.0
# 5        41.0
# ...

# %%
### 데이터 타입

ATM_monthly_df.dtypes
# Out:
# 측정월               int64
# 측정소명             object
# 이산화질소농도(ppm)    float64
# 오존농도(ppm)       float64
# 일산화탄소농도(ppm)    float64
# 아황산가스(ppm)      float64
# 미세먼지(㎍/㎥)       float64
# 초미세먼지(㎍/㎥)      float64
# dtype: object

# %%
### 데이터의 shape

ATM_monthly_df.shape
# Out:
# (13840, 8)

# %%
### 결측치

ATM_monthly_df.isnull().sum()
# Out:
# 측정월                0
# 측정소명               0
# 이산화질소농도(ppm)     474
# 오존농도(ppm)        736
# 일산화탄소농도(ppm)     499
# 아황산가스(ppm)       758
# 미세먼지(㎍/㎥)       2422
# 초미세먼지(㎍/㎥)      8620
# dtype: int64

# %% [markdown]
# ##### **서대문구 2022년**
#
# 연도별 데이터와 달리 월별 데이터는 1년 중 월별로 어떠한 변화가 나타나는지 볼 수 있다는 장점이 있다.
# 2022년 1년의 기간을 잡아서 월별 변화를 보다 자세히 살펴보고자 한다.

# %%
### 서대문구 데이터프레임 분리

# pd.set_option('display.max_rows', None) # 모든 데이터 보기
seodaemun_monthly = ATM_monthly_df.loc[ATM_monthly_df['측정소명'] == '서대문구']
seodaemun_monthly.head()
# Out:
#         측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 22   202301  서대문구         0.034      0.015           0.9       0.006
# 72   202212  서대문구         0.026      0.016           0.7       0.004
# 122  202211  서대문구         0.023      0.020           0.8       0.004
# 172  202210  서대문구         0.015      0.020           0.5       0.003
# 222  202209  서대문구         0.010      0.026           0.4       0.003
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 22        61.0        39.0
# 72        36.0        17.0
# 122       37.0        21.0
# 172       22.0        11.0
# 222       19.0        10.0

# %%
### 서대문구 최댓값, 최솟값, 평균

print('서대문구 최댓값: --------------------')
print(seodaemun_monthly.max()[['이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)', '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']])

print('\n서대문구 최솟값: --------------------')
print(seodaemun_monthly.min()[['이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)', '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']])

print('\n서대문구 평균: --------------------')
print(seodaemun_monthly.mean()[['이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)', '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']])
# Out:
# 서대문구 최댓값: --------------------
# 이산화질소농도(ppm)    0.071
# 오존농도(ppm)       0.052
# 일산화탄소농도(ppm)      8.7
# 아황산가스(ppm)      0.211
# 미세먼지(㎍/㎥)       113.0
# 초미세먼지(㎍/㎥)       48.0
# dtype: object
#
# 서대문구 최솟값: --------------------
# 이산화질소농도(ppm)    0.007
# 오존농도(ppm)       0.003
# 일산화탄소농도(ppm)      0.2
# 아황산가스(ppm)      0.001
# 미세먼지(㎍/㎥)        11.0
# 초미세먼지(㎍/㎥)        6.0
# dtype: object
#
# 서대문구 평균: --------------------
# 이산화질소농도(ppm)     0.032612
# 오존농도(ppm)        0.018542
# 일산화탄소농도(ppm)     1.164455
# 아황산가스(ppm)       0.016429
# 미세먼지(㎍/㎥)       50.056537
# 초미세먼지(㎍/㎥)      21.561404
# dtype: float64
# C:\Users\izzle\AppData\Local\Temp\ipykernel_15088\54788818.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
seodaemun_monthly_22 = seodaemun_monthly.loc[72:623, :]
seodaemun_monthly_22
# Out:
#         측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 72   202212  서대문구         0.026      0.016           0.7       0.004
# 122  202211  서대문구         0.023      0.020           0.8       0.004
# 172  202210  서대문구         0.015      0.020           0.5       0.003
# 222  202209  서대문구         0.010      0.026           0.4       0.003
# 272  202208  서대문구         0.011      0.030           0.4       0.002
# 322  202207  서대문구         0.011      0.037           0.4       0.002
# 372  202206  서대문구         0.010      0.035           0.4       0.003
# 422  202205  서대문구         0.013      0.052           0.4       0.004
# 472  202204  서대문구         0.017      0.047           0.5       0.003
# 522  202203  서대문구         0.022      0.032           0.7       0.003
# 572  202202  서대문구         0.025      0.026           0.7       0.004
# 622  202201  서대문구         0.031      0.016           0.8       0.005
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 72        36.0        17.0
# ...

# %%
### 이산화질소 농도 내림차순 정렬

seodaemun_monthly_22.sort_values(by='이산화질소농도(ppm)', ascending=False, inplace=False).head()

# 이산화질소 농도는 주로 겨울에 높은 것으로 보인다
# Out:
#         측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 622  202201  서대문구         0.031      0.016           0.8       0.005
# 72   202212  서대문구         0.026      0.016           0.7       0.004
# 572  202202  서대문구         0.025      0.026           0.7       0.004
# 122  202211  서대문구         0.023      0.020           0.8       0.004
# 522  202203  서대문구         0.022      0.032           0.7       0.003
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 622       42.0        28.0
# 72        36.0        17.0
# 572       39.0        26.0
# 122       37.0        21.0
# 522       42.0        21.0

# %%
### 오존 농도 내림차순 정렬

seodaemun_monthly_22.sort_values(by='오존농도(ppm)', ascending=False, inplace=False).head()

# 오존 농도는 주로 봄, 여름에 높은 것으로 보인다
# Out:
#         측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 422  202205  서대문구         0.013      0.052           0.4       0.004
# 472  202204  서대문구         0.017      0.047           0.5       0.003
# 322  202207  서대문구         0.011      0.037           0.4       0.002
# 372  202206  서대문구         0.010      0.035           0.4       0.003
# 522  202203  서대문구         0.022      0.032           0.7       0.003
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 422       33.0        15.0
# 472       44.0        18.0
# 322       22.0        12.0
# 372       20.0        10.0
# 522       42.0        21.0

# %%
### 일산화탄소 농도 내림차순 정렬

seodaemun_monthly_22.sort_values(by='일산화탄소농도(ppm)', ascending=False, inplace=False).head()

# 일산화탄소 농도는 주로 겨울에 높은 것으로 보인다
# Out:
#         측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 122  202211  서대문구         0.023      0.020           0.8       0.004
# 622  202201  서대문구         0.031      0.016           0.8       0.005
# 72   202212  서대문구         0.026      0.016           0.7       0.004
# 522  202203  서대문구         0.022      0.032           0.7       0.003
# 572  202202  서대문구         0.025      0.026           0.7       0.004
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 122       37.0        21.0
# 622       42.0        28.0
# 72        36.0        17.0
# 522       42.0        21.0
# 572       39.0        26.0

# %%
### 아황산가스 내림차순 정렬

seodaemun_monthly_22.sort_values(by='아황산가스(ppm)', ascending=False, inplace=False).head()

# 아황산가스는 주로 겨울에 높은 것으로 보인다
# Out:
#         측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 622  202201  서대문구         0.031      0.016           0.8       0.005
# 72   202212  서대문구         0.026      0.016           0.7       0.004
# 122  202211  서대문구         0.023      0.020           0.8       0.004
# 422  202205  서대문구         0.013      0.052           0.4       0.004
# 572  202202  서대문구         0.025      0.026           0.7       0.004
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 622       42.0        28.0
# 72        36.0        17.0
# 122       37.0        21.0
# 422       33.0        15.0
# 572       39.0        26.0

# %%
### 미세먼지 농도 내림차순 정렬

seodaemun_monthly_22.sort_values(by='미세먼지(㎍/㎥)', ascending=False, inplace=False).head()

# 미세먼지 농도는 주로 봄에 높은 것으로 보인다
# Out:
#         측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 472  202204  서대문구         0.017      0.047           0.5       0.003
# 522  202203  서대문구         0.022      0.032           0.7       0.003
# 622  202201  서대문구         0.031      0.016           0.8       0.005
# 572  202202  서대문구         0.025      0.026           0.7       0.004
# 122  202211  서대문구         0.023      0.020           0.8       0.004
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 472       44.0        18.0
# 522       42.0        21.0
# 622       42.0        28.0
# 572       39.0        26.0
# 122       37.0        21.0

# %%
### 초미세먼지 농도 내림차순 정렬

seodaemun_monthly_22.sort_values(by='초미세먼지(㎍/㎥)', ascending=False, inplace=False).head()

# 초미세먼지 농도는 주로 겨울, 봄에 높은 것으로 보인다
# Out:
#         측정월  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 622  202201  서대문구         0.031      0.016           0.8       0.005
# 572  202202  서대문구         0.025      0.026           0.7       0.004
# 122  202211  서대문구         0.023      0.020           0.8       0.004
# 522  202203  서대문구         0.022      0.032           0.7       0.003
# 472  202204  서대문구         0.017      0.047           0.5       0.003
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 622       42.0        28.0
# 572       39.0        26.0
# 122       37.0        21.0
# 522       42.0        21.0
# 472       44.0        18.0

# %% [markdown]
# ##### **각 오염물질별 계절성 정리**
#
# * 이산화질소: 주로 겨울에 높은 것으로 보인다
# * 오존: 주로 봄, 여름에 높은 것으로 보인다
# * 일산화탄소: 주로 겨울에 높은 것으로 보인다
# * 아황산가스: 주로 겨울에 높은 것으로 보인다
# * 미세먼지: 주로 봄에 높은 것으로 보인다
# * 초미세먼지: 주로 겨울, 봄에 높은 것으로 보인다

# %% [markdown]
# ##### **서울시 시간 평균 대기오염도 정보**

# %%
### '서울시 시간 평균 대기오염도 정보.csv'를 ATM_hourly_df라는 데이터프레임 형태로 불러오기

ATM_hourly_df = pd.read_csv('C:/Users/izzle/Downloads/서울시 시간 평균 대기오염도 정보.csv', encoding='cp949')
ATM_hourly_df.head(10)
# Out:
#            측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 0  202301082000   노원구         0.050      0.010           0.9       0.003
# 1  202301082000   도봉구         0.038      0.009           0.9       0.002
# 2  202301082000   서초구         0.043      0.006           0.7       0.003
# 3  202301082000   관악구         0.054      0.003           0.9       0.003
# 4  202301082000   구로구         0.047      0.003           0.6       0.003
# 5  202301082000   중랑구         0.033      0.021           0.7       0.003
# 6  202301082000  서대문구         0.038      0.011           0.8       0.004
# 7  202301082000  동대문구         0.036      0.013           0.8       0.003
# 8  202301082000   송파구         0.044      0.006           0.9       0.003
# 9  202301082000   마포구         0.046      0.007           0.8       0.004
#
#    미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0      123.0        59.0
# 1      109.0        53.0
# 2      115.0        62.0
# 3      114.0        47.0
# 4      119.0        58.0
# ...

# %%
### 데이터 타입

ATM_hourly_df.dtypes
# Out:
# 측정일시              int64
# 측정소명             object
# 이산화질소농도(ppm)    float64
# 오존농도(ppm)       float64
# 일산화탄소농도(ppm)    float64
# 아황산가스(ppm)      float64
# 미세먼지(㎍/㎥)       float64
# 초미세먼지(㎍/㎥)      float64
# dtype: object

# %%
### 데이터의 shape

ATM_hourly_df.shape
# Out:
# (4225, 8)

# %%
### 결측치

ATM_hourly_df.isnull().sum()
# Out:
# 측정일시             0
# 측정소명             0
# 이산화질소농도(ppm)    48
# 오존농도(ppm)       34
# 일산화탄소농도(ppm)    34
# 아황산가스(ppm)      36
# 미세먼지(㎍/㎥)       79
# 초미세먼지(㎍/㎥)      57
# dtype: int64

# %% [markdown]
# ##### **서대문구 2023년 1월 7일**
#
# 시간 평균 데이터는 하루 중 시간별로 어떠한 변화가 나타나는지, 즉 일변화를 볼 수 있다는 장점이 있다.
# 2023년 1월 7일 하루 동안의 기간을 잡아서 일변화를 보다 자세히 살펴보고자 한다.

# %%
### 서대문구 데이터프레임 분리

# pd.set_option('display.max_rows', None) # 모든 데이터 보기
seodaemun_hourly = ATM_hourly_df.loc[ATM_hourly_df['측정소명'] == '서대문구']
seodaemun_hourly.head()
# Out:
#              측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 6    202301082000  서대문구         0.038      0.011           0.8       0.004
# 34   202301081900  서대문구         0.043      0.009           0.8       0.004
# 67   202301081800  서대문구         0.041      0.011           0.7       0.004
# 79   202301081700  서대문구         0.037      0.015           0.7       0.005
# 122  202301081600  서대문구         0.032      0.019           0.6       0.005
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 6        111.0        53.0
# 34       120.0        51.0
# 67       110.0        46.0
# 79       106.0        44.0
# 122      116.0        49.0

# %%
### 서대문구 최댓값, 최솟값, 평균

print('서대문구 최댓값: --------------------')
print(seodaemun_hourly.max()[['이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)', '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']])

print('\n서대문구 최솟값: --------------------')
print(seodaemun_hourly.min()[['이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)', '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']])

print('\n서대문구 평균: --------------------')
print(seodaemun_hourly.mean()[['이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)', '아황산가스(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)']])
# Out:
# 서대문구 최댓값: --------------------
# 이산화질소농도(ppm)    0.068
# 오존농도(ppm)       0.037
# 일산화탄소농도(ppm)      2.1
# 아황산가스(ppm)      0.013
# 미세먼지(㎍/㎥)       175.0
# 초미세먼지(㎍/㎥)      108.0
# dtype: object
#
# 서대문구 최솟값: --------------------
# 이산화질소농도(ppm)    0.011
# 오존농도(ppm)       0.003
# 일산화탄소농도(ppm)      0.2
# 아황산가스(ppm)      0.003
# 미세먼지(㎍/㎥)        15.0
# 초미세먼지(㎍/㎥)        6.0
# dtype: object
#
# 서대문구 평균: --------------------
# 이산화질소농도(ppm)     0.034911
# 오존농도(ppm)        0.014598
# 일산화탄소농도(ppm)     0.900592
# 아황산가스(ppm)       0.006006
# 미세먼지(㎍/㎥)       61.886905
# 초미세먼지(㎍/㎥)      38.147929
# dtype: float64
# C:\Users\izzle\AppData\Local\Temp\ipykernel_15088\1314779377.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
seodaemun_hourly_22 = seodaemun_hourly.loc[526:1101, :]
seodaemun_hourly_22
# Out:
#               측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 526   202301072300  서대문구         0.022      0.022           1.0       0.007
# 561   202301072200  서대문구         0.043      0.011           1.5       0.006
# 588   202301072100  서대문구         0.049      0.005           1.8       0.006
# 601   202301072000  서대문구         0.045      0.010           1.7       0.006
# 649   202301071900  서대문구         0.026      0.029           1.5       0.006
# 653   202301071800  서대문구         0.029      0.030           1.2       0.004
# 676   202301071700  서대문구         0.023      0.034           1.2       0.005
# 704   202301071600  서대문구         0.020      0.036           1.2       0.005
# 743   202301071500  서대문구         0.018      0.037           1.1       0.005
# 755   202301071400  서대문구         0.018      0.032           1.1       0.005
# 789   202301071300  서대문구         0.018      0.029           1.1       0.005
# ...

# %%
### 이산화질소 농도 내림차순 정렬

seodaemun_hourly_22.sort_values(by='이산화질소농도(ppm)', ascending=False, inplace=False).head()

# 이산화질소 농도는 주로 밤, 새벽 시간대에 높은 것으로 보인다
# Out:
#               측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 588   202301072100  서대문구         0.049      0.005           1.8       0.006
# 1029  202301070300  서대문구         0.047      0.004           1.3       0.004
# 601   202301072000  서대문구         0.045      0.010           1.7       0.006
# 561   202301072200  서대문구         0.043      0.011           1.5       0.006
# 1068  202301070200  서대문구         0.042      0.008           1.2       0.004
#
#       미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 588       120.0       100.0
# 1029       89.0        84.0
# 601       122.0        92.0
# 561       108.0        87.0
# 1068       81.0        77.0

# %%
### 오존 농도 내림차순 정렬

seodaemun_hourly_22.sort_values(by='오존농도(ppm)', ascending=False, inplace=False).head()

# 오존 농도는 주로 낮, 오후 시간대에 높은 것으로 보인다
# Out:
#              측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 743  202301071500  서대문구         0.018      0.037           1.1       0.005
# 704  202301071600  서대문구         0.020      0.036           1.2       0.005
# 676  202301071700  서대문구         0.023      0.034           1.2       0.005
# 755  202301071400  서대문구         0.018      0.032           1.1       0.005
# 653  202301071800  서대문구         0.029      0.030           1.2       0.004
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 743      153.0       104.0
# 704      137.0       104.0
# 676      127.0       104.0
# 755      158.0       104.0
# 653      128.0        98.0

# %%
### 일산화탄소 농도 내림차순 정렬

seodaemun_hourly_22.sort_values(by='일산화탄소농도(ppm)', ascending=False, inplace=False).head()

# 일산화탄소 농도는 주로 밤 시간대에 높은 것으로 보인다
# Out:
#               측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 588   202301072100  서대문구         0.049      0.005           1.8       0.006
# 601   202301072000  서대문구         0.045      0.010           1.7       0.006
# 649   202301071900  서대문구         0.026      0.029           1.5       0.006
# 561   202301072200  서대문구         0.043      0.011           1.5       0.006
# 1029  202301070300  서대문구         0.047      0.004           1.3       0.004
#
#       미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 588       120.0       100.0
# 601       122.0        92.0
# 649       120.0        91.0
# 561       108.0        87.0
# 1029       89.0        84.0

# %%
### 아황산가스 내림차순 정렬

seodaemun_hourly_22.sort_values(by='아황산가스(ppm)', ascending=False, inplace=False).head()

# 아황산가스는 주로 밤 시간대에 높은 것으로 보인다
# Out:
#              측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 526  202301072300  서대문구         0.022      0.022           1.0       0.007
# 588  202301072100  서대문구         0.049      0.005           1.8       0.006
# 601  202301072000  서대문구         0.045      0.010           1.7       0.006
# 649  202301071900  서대문구         0.026      0.029           1.5       0.006
# 561  202301072200  서대문구         0.043      0.011           1.5       0.006
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 526      123.0        83.0
# 588      120.0       100.0
# 601      122.0        92.0
# 649      120.0        91.0
# 561      108.0        87.0

# %%
### 미세먼지 농도 내림차순 정렬

seodaemun_hourly_22.sort_values(by='미세먼지(㎍/㎥)', ascending=False, inplace=False).head()

# 미세먼지 농도는 주로 낮 시간대에 높은 것으로 보인다
# Out:
#              측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 755  202301071400  서대문구         0.018      0.032           1.1       0.005
# 743  202301071500  서대문구         0.018      0.037           1.1       0.005
# 789  202301071300  서대문구         0.018      0.029           1.1       0.005
# 704  202301071600  서대문구         0.020      0.036           1.2       0.005
# 653  202301071800  서대문구         0.029      0.030           1.2       0.004
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 755      158.0       104.0
# 743      153.0       104.0
# 789      144.0        96.0
# 704      137.0       104.0
# 653      128.0        98.0

# %%
### 초미세먼지 농도 내림차순 정렬

seodaemun_hourly_22.sort_values(by='초미세먼지(㎍/㎥)', ascending=False, inplace=False).head()

# 초미세먼지 농도는 주로 아침 및 낮 시간대에 높은 것으로 보인다
# Out:
#              측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스(ppm)  \
# 952  202301070600  서대문구         0.025      0.016           0.9       0.004
# 942  202301070700  서대문구         0.023      0.018           0.9       0.004
# 676  202301071700  서대문구         0.023      0.034           1.2       0.005
# 743  202301071500  서대문구         0.018      0.037           1.1       0.005
# 704  202301071600  서대문구         0.020      0.036           1.2       0.005
#
#      미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 952      127.0       108.0
# 942      121.0       107.0
# 676      127.0       104.0
# 743      153.0       104.0
# 704      137.0       104.0

# %% [markdown]
# ##### **각 오염물질별 일변화 정리**
#
# * 이산화질소: 주로 밤, 새벽 시간대에 높은 것으로 보인다
# * 오존: 주로 낮, 오후 시간대에 높은 것으로 보인다
# * 일산화탄소: 주로 밤 시간대에 높은 것으로 보인다
# * 아황산가스: 주로 밤 시간대에 높은 것으로 보인다
# * 미세먼지: 주로 낮 시간대에 높은 것으로 보인다
# * 초미세먼지: 주로 아침 및 낮 시간대에 높은 것으로 보인다
