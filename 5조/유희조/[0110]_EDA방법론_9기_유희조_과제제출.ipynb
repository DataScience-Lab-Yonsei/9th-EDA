# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **남양주시 직행버스 -> 강남역 종점**

# %%
namyangju_2210 = pd.read_csv("/content/drive/MyDrive/DSL/EDA/2210_남양주_1700,2000,7007.xls.csv", encoding = 'cp949')
namyangju_2211 = pd.read_csv("/content/drive/MyDrive/DSL/EDA/2211_남양주_1700,2000,7007_수정본.xls.csv")

# %%
namyangju_2210.head()
# Out:
#      년도   월    지역    노선          시?종점 (출발?도착지점)  일시       시간   승차   하차   전체  \
# 0  2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  05시~06시   52   25   77
# 1  2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  06시~07시  120   50  170
# 2  2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  07시~08시  105   84  189
# 3  2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  08시~09시   73  118  191
# 4  2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  09시~10시   35   67  102
#
#    승차.1  하차.1  전체.1  승차.2  하차.2  전체.2
# 0     8     1     9    60    26    86
# 1    13    11    24   133    61   194
# 2    26    24    50   131   108   239
# 3    86    89   175   159   207   366
# 4    36    33    69    71   100   171

# %%
namyangju_2211.head()
# Out:
#      년도   월    지역    노선          시•종점 (출발•도착지점)  일시       시간   승차   하차   전체  \
# 0  2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  05시~06시   43   21   64
# 1  2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  06시~07시  100   38  138
# 2  2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  07시~08시  126   76  202
# 3  2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  08시~09시   94  126  220
# 4  2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  09시~10시   44  103  147
#
#    승차.1  하차.1  전체.1  승차.2  하차.2  전체.2
# 0     6     1     7    49    22    71
# 1    25    14    39   125    52   177
# 2    34    35    69   160   111   271
# 3    55    51   106   149   177   326
# 4    38    48    86    82   151   233

# %% [markdown]
# **출근 시간대_2210**

# %%
con_1 = namyangju_2210['시간'] == '05시~06시'
con_2 = namyangju_2210['시간'] == '06시~07시'
con_3 = namyangju_2210['시간'] == '07시~08시'

# %%
namyangju_2210.loc[con_1 | con_2 | con_3 ,  ]
# Out:
#       년도   월    지역    노선          시?종점 (출발?도착지점)  일시       시간   승차  하차   전체  \
# 0   2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  05시~06시   52  25   77
# 1   2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  06시~07시  120  50  170
# 2   2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  07시~08시  105  84  189
# 21  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  05시~06시   83   1   84
# 22  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  06시~07시  135  97  232
# 23  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  07시~08시  160  67  227
# 42  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  05시~06시   74   1   75
# 43  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  06시~07시  162  55  217
# 44  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  07시~08시  137  97  234
#
#     승차.1  하차.1  전체.1  승차.2  하차.2  전체.2
# 0      8     1     9    60    26    86
# 1     13    11    24   133    61   194
# 2     26    24    50   131   108   239
# 21     3     0     3    86     1    87
# ...

# %%
a = namyangju_2210[namyangju_2212['시간'] == '05시~06시']

# %%
b = namyangju_2210[namyangju_2212['시간'] == '06시~07시']

# %%
c = namyangju_2210[namyangju_2212['시간'] == '07시~08시']

# %%
am_2210 = pd.concat([a, b, c])
am_2210
# Out:
#       년도   월    지역    노선          시?종점 (출발?도착지점)  일시       시간   승차  하차   전체  \
# 0   2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  05시~06시   52  25   77
# 21  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  05시~06시   83   1   84
# 42  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  05시~06시   74   1   75
# 1   2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  06시~07시  120  50  170
# 22  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  06시~07시  135  97  232
# 43  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  06시~07시  162  55  217
# 2   2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  07시~08시  105  84  189
# 23  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  07시~08시  160  67  227
# 44  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  07시~08시  137  97  234
#
#     승차.1  하차.1  전체.1  승차.2  하차.2  전체.2
# 0      8     1     9    60    26    86
# 21     3     0     3    86     1    87
# 42     1     0     1    75     1    76
# 1     13    11    24   133    61   194
# ...

# %% [markdown]
# **출근 시간대_2211**

# %%
d = namyangju_2211[namyangju_2211['시간'] == '05시~06시']

# %%
e = namyangju_2211[namyangju_2211['시간'] == '06시~07시']

# %%
f = namyangju_2211[namyangju_2211['시간'] == '07시~08시']

# %%
am_2211 = pd.concat([d, e, f])
am_2211
# Out:
#       년도   월    지역    노선          시•종점 (출발•도착지점)  일시       시간   승차   하차   전체  \
# 0   2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  05시~06시   43   21   64
# 22  2022  11  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  05시~06시   90    2   92
# 43  2022  11  남양주시  7007          광릉내-강남역.강남역사거리  평일  05시~06시   76   17   93
# 1   2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  06시~07시  100   38  138
# 23  2022  11  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  06시~07시  130   85  215
# 44  2022  11  남양주시  7007          광릉내-강남역.강남역사거리  평일  06시~07시  158   39  197
# 2   2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  07시~08시  126   76  202
# 24  2022  11  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  07시~08시  127  102  229
# 45  2022  11  남양주시  7007          광릉내-강남역.강남역사거리  평일  07시~08시  143   90  233
#
#     승차.1  하차.1  전체.1  승차.2  하차.2  전체.2
# 0      6     1     7    49    22    71
# 22     2     0     2    92     2    94
# 43     2     1     3    78    18    96
# 1     25    14    39   125    52   177
# ...

# %% [markdown]
# **10월, 11월 출근 시간대**

# %%
am_2210_df = am_2210.loc[:, ['년도', '월', '지역', '노선', '시간', '승차.2']]
am_2211_df = am_2211.loc[:, ['년도', '월', '지역', '노선', '시간', '승차.2']]

# %%
am = pd.merge(am_2210_df, am_2211_df, how = 'left', on = '노선')
am
# Out:
#     년도_x  월_x  지역_x    노선     시간_x  승차.2_x  년도_y  월_y  지역_y     시간_y  승차.2_y
# 0   2022   10  남양주시  1700  05시~06시      60  2022   11  남양주시  05시~06시      49
# 1   2022   10  남양주시  1700  05시~06시      60  2022   11  남양주시  06시~07시     125
# 2   2022   10  남양주시  1700  05시~06시      60  2022   11  남양주시  07시~08시     160
# 3   2022   10  남양주시  2000  05시~06시      86  2022   11  남양주시  05시~06시      92
# 4   2022   10  남양주시  2000  05시~06시      86  2022   11  남양주시  06시~07시     134
# 5   2022   10  남양주시  2000  05시~06시      86  2022   11  남양주시  07시~08시     156
# 6   2022   10  남양주시  7007  05시~06시      75  2022   11  남양주시  05시~06시      78
# 7   2022   10  남양주시  7007  05시~06시      75  2022   11  남양주시  06시~07시     167
# 8   2022   10  남양주시  7007  05시~06시      75  2022   11  남양주시  07시~08시     195
# 9   2022   10  남양주시  1700  06시~07시     133  2022   11  남양주시  05시~06시      49
# 10  2022   10  남양주시  1700  06시~07시     133  2022   11  남양주시  06시~07시     125
# ...

# %%
am_group = am.groupby(['시간_x', '노선'])
am_group.mean()
# Out:
#                 년도_x   월_x  승차.2_x    년도_y   월_y      승차.2_y
# 시간_x    노선
# 05시~06시 1700  2022.0  10.0    60.0  2022.0  11.0  111.333333
#         2000  2022.0  10.0    86.0  2022.0  11.0  127.333333
#         7007  2022.0  10.0    75.0  2022.0  11.0  146.666667
# 06시~07시 1700  2022.0  10.0   133.0  2022.0  11.0  111.333333
#         2000  2022.0  10.0   138.0  2022.0  11.0  127.333333
#         7007  2022.0  10.0   175.0  2022.0  11.0  146.666667
# 07시~08시 1700  2022.0  10.0   131.0  2022.0  11.0  111.333333
#         2000  2022.0  10.0   193.0  2022.0  11.0  127.333333
#         7007  2022.0  10.0   176.0  2022.0  11.0  146.666667

# %% [markdown]
# **퇴근 시간대_2210**

# %%
A = namyangju_2210[namyangju_2210['시간'] == '17시~18시']

# %%
B = namyangju_2210[namyangju_2210['시간'] == '18시~19시']

# %%
C = namyangju_2210[namyangju_2210['시간'] == '19시~20시']

# %%
pm_2210 = pd.concat([A, B, C])
pm_2210
# Out:
#       년도   월    지역    노선          시?종점 (출발?도착지점)  일시       시간   승차   하차   전체  \
# 12  2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  17시~18시   66   60  126
# 33  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  17시~18시  177  182  359
# 54  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  17시~18시   85   57  142
# 13  2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  18시~19시   68   50  118
# 34  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  18시~19시  185  101  286
# 55  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  18시~19시   98   75  173
# 14  2022  10  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  19시~20시   59   80  139
# 35  2022  10  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  19시~20시  118  158  276
# 56  2022  10  남양주시  7007          광릉내-강남역.강남역사거리  평일  19시~20시   79   94  173
#
#     승차.1  하차.1  전체.1  승차.2  하차.2  전체.2
# 12    44    39    83   110    99   209
# 33    54    52   106   231   234   465
# 54    41    45    86   126   102   228
# 13    28    17    45    96    67   163
# ...

# %% [markdown]
# **퇴근 시간대_2211**

# %%
D = namyangju_2211[namyangju_2211['시간'] == '17시~18시']

# %%
E = namyangju_2211[namyangju_2211['시간'] == '18시~19시']

# %%
F = namyangju_2211[namyangju_2211['시간'] == '19시~20시']

# %%
pm_2211 = pd.concat([D, E, F])
pm_2211
# Out:
#       년도   월    지역    노선          시•종점 (출발•도착지점)  일시       시간   승차   하차   전체  \
# 12  2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  17시~18시   63   60  123
# 34  2022  11  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  17시~18시  149  112  261
# 55  2022  11  남양주시  7007          광릉내-강남역.강남역사거리  평일  17시~18시   79   47  126
# 13  2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  18시~19시   73   43  116
# 35  2022  11  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  18시~19시  169  142  311
# 56  2022  11  남양주시  7007          광릉내-강남역.강남역사거리  평일  18시~19시   88   75  163
# 14  2022  11  남양주시  1700  연대농장입구.도곡리종점-신논현역.우신빌딩  평일  19시~20시   68   81  149
# 36  2022  11  남양주시  2000   진벌리차고지(경유)-강남역.강남역사거리  평일  19시~20시   86  122  208
# 57  2022  11  남양주시  7007          광릉내-강남역.강남역사거리  평일  19시~20시   59   92  151
#
#     승차.1  하차.1  전체.1  승차.2  하차.2  전체.2
# 12    31    34    65    94    94   188
# 34    58    37    95   207   149   356
# 55    39    19    58   118    66   184
# 13    52    19    71   125    62   187
# ...

# %% [markdown]
# **10월, 11월 퇴근 시간대**

# %%
pm_2210_df = pm_2210.loc[:, ['년도', '월', '지역', '노선', '시간', '승차.2']]
pm_2211_df = pm_2211.loc[:, ['년도', '월', '지역', '노선', '시간', '승차.2']]

# %%
pm = pd.merge(pm_2210_df, pm_2211_df, how = 'left', on = '노선')
pm
# Out:
#     년도_x  월_x  지역_x    노선     시간_x  승차.2_x  년도_y  월_y  지역_y     시간_y  승차.2_y
# 0   2022   10  남양주시  1700  17시~18시     110  2022   11  남양주시  17시~18시      94
# 1   2022   10  남양주시  1700  17시~18시     110  2022   11  남양주시  18시~19시     125
# 2   2022   10  남양주시  1700  17시~18시     110  2022   11  남양주시  19시~20시     118
# 3   2022   10  남양주시  2000  17시~18시     231  2022   11  남양주시  17시~18시     207
# 4   2022   10  남양주시  2000  17시~18시     231  2022   11  남양주시  18시~19시     234
# 5   2022   10  남양주시  2000  17시~18시     231  2022   11  남양주시  19시~20시     149
# 6   2022   10  남양주시  7007  17시~18시     126  2022   11  남양주시  17시~18시     118
# 7   2022   10  남양주시  7007  17시~18시     126  2022   11  남양주시  18시~19시     149
# 8   2022   10  남양주시  7007  17시~18시     126  2022   11  남양주시  19시~20시     118
# 9   2022   10  남양주시  1700  18시~19시      96  2022   11  남양주시  17시~18시      94
# 10  2022   10  남양주시  1700  18시~19시      96  2022   11  남양주시  18시~19시     125
# ...

# %%
pm_group = pm.groupby(['시간_x', '노선'])
pm_group.mean()
# Out:
#                 년도_x   월_x  승차.2_x    년도_y   월_y      승차.2_y
# 시간_x    노선
# 17시~18시 1700  2022.0  10.0   110.0  2022.0  11.0  112.333333
#         2000  2022.0  10.0   231.0  2022.0  11.0  196.666667
#         7007  2022.0  10.0   126.0  2022.0  11.0  128.333333
# 18시~19시 1700  2022.0  10.0    96.0  2022.0  11.0  112.333333
#         2000  2022.0  10.0   252.0  2022.0  11.0  196.666667
#         7007  2022.0  10.0   151.0  2022.0  11.0  128.333333
# 19시~20시 1700  2022.0  10.0   114.0  2022.0  11.0  112.333333
#         2000  2022.0  10.0   176.0  2022.0  11.0  196.666667
#         7007  2022.0  10.0   123.0  2022.0  11.0  128.333333
