# %% [markdown]
# # **EDA방법론 세션 이후 과제(~230116)**
# 노선별 t-test 진행(9월 vs. 11월)
# EDA 5조 이성균

# %% [markdown]
# ### **13145 연세로.명물거리(세브란스병원 방면) (타코벨 앞)**
# 171, 172, 173, 472, 674, 700, 7024, 서대문03, 서대문04, 서대문05
# ### **13146 연세로.스타광장(현대백화점 방면) (유플렉스 앞)**
# 7720, 7727, 7728, 72, 75
# ### **13324 연세로.문학의거리(연세로.명물거리 방면) (playground 앞)**
# 171, 172, 173, 472, 674, 700, 7024

# %% [markdown]
# 차 없는 거리 : 2014년 1월 연세로가 서울시 첫 대중교통전용지구로 지정됨, 왕복 4차로를 2차로로 줄이고 인도 확장. 2018년 4월부터는 금요일 오후 2시부터 버스도 금지해 완전히 차 없는 거리로 만듦(더불어민주당 문석진 전 서대문구청장)
#
# 차 없는 거리 해제 : 국민의힘 이성헌 현 서대문구청장 취임(2022.07.01.) 이후, 2022년 10월 9일 오후 10시부터 주말에도 버스 통행 가능, 2023년 1월 20일부터 9월 30일까지 대중교통전용지구 해제 시범운영 및 24시간 전일 차량 통행 가능
#
# 전후 변화 : 2022년 10월 9일 전후 13145, 13324 승하차인원 추이 비교 - 9월과 11월의 승차인원 평균이 차이가 있는지 이표본 이분산 t-검정 수행

# %% [markdown]
# 불리언 인덱싱, loc 함수를 통해 필요한 정보들만 뽑아내어 시각화하려고 시도함.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
B2212 = pd.read_csv('/content/drive/MyDrive/DSL_EDA/BUS_STATION_BOARDING_MONTH_202212.csv', encoding = 'cp949')
B2211 = pd.read_csv('/content/drive/MyDrive/DSL_EDA/BUS_STATION_BOARDING_MONTH_202211.csv', encoding = 'cp949')
B2210 = pd.read_csv('/content/drive/MyDrive/DSL_EDA/BUS_STATION_BOARDING_MONTH_202210.csv', encoding = 'cp949')
B2209 = pd.read_csv('/content/drive/MyDrive/DSL_EDA/BUS_STATION_BOARDING_MONTH_202209.csv', encoding = 'cp949')
B2208 = pd.read_csv('/content/drive/MyDrive/DSL_EDA/BUS_STATION_BOARDING_MONTH_202208.csv', encoding = 'cp949')
B2207 = pd.read_csv('/content/drive/MyDrive/DSL_EDA/BUS_STATION_BOARDING_MONTH_202207.csv', encoding = 'cp949')

# %%
# 서대문03 (타코벨 앞 정류장)
tt = B2212[B2212['노선번호']=='서대문03']
B2212_S03 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2211[B2211['노선번호']=='서대문03']
B2211_S03 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2210[B2210['노선번호']=='서대문03']
B2210_S03 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2209[B2209['노선번호']=='서대문03']
B2209_S03 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2208[B2208['노선번호']=='서대문03']
B2208_S03 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2207[B2207['노선번호']=='서대문03']
B2207_S03 = tt[tt['버스정류장ARS번호']=='13145']

# %%
# 서대문04 (타코벨 앞 정류장)
tt = B2212[B2212['노선번호']=='서대문04']
B2212_S04 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2211[B2211['노선번호']=='서대문04']
B2211_S04 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2210[B2210['노선번호']=='서대문04']
B2210_S04 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2209[B2209['노선번호']=='서대문04']
B2209_S04 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2208[B2208['노선번호']=='서대문04']
B2208_S04 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2207[B2207['노선번호']=='서대문04']
B2207_S04 = tt[tt['버스정류장ARS번호']=='13145']

# %%
# 서대문05 (타코벨 앞 정류장)
tt = B2212[B2212['노선번호']=='서대문05']
B2212_S05 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2211[B2211['노선번호']=='서대문05']
B2211_S05 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2210[B2210['노선번호']=='서대문05']
B2210_S05 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2209[B2209['노선번호']=='서대문05']
B2209_S05 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2208[B2208['노선번호']=='서대문05']
B2208_S05 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2207[B2207['노선번호']=='서대문05']
B2207_S05 = tt[tt['버스정류장ARS번호']=='13145']

# %%
# 7024 (타코벨 앞 정류장)
tt = B2212[B2212['노선번호']=='7024']
B2212_7024 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2211[B2211['노선번호']=='7024']
B2211_7024 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2210[B2210['노선번호']=='7024']
B2210_7024 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2209[B2209['노선번호']=='7024']
B2209_7024 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2208[B2208['노선번호']=='7024']
B2208_7024 = tt[tt['버스정류장ARS번호']=='13145']
tt = B2207[B2207['노선번호']=='7024']
B2207_7024 = tt[tt['버스정류장ARS번호']=='13145']

# %% [markdown]
# 사용일자를 datetime 패키지 사용해서 요일 입력 후, 금~일 제외해서(차 없는 거리 : 금요일 오후 2시부터 일요일 자정까지) df 새로 생성

# %%
import datetime
days = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
date = []
for i in range(0,len(pd.DataFrame(B2212_S03['사용일자']))):
  a = pd.DataFrame(B2212_S03['사용일자']).iat[i,0]
  date.append(days[datetime.date(int(str(a)[0:4]),int(str(a)[4:6]),int(str(a)[6:8])).weekday()])

# 요일 컬럼 집어넣기
B2212_S03.insert(0,'요일',date)

# 금, 토, 일 해당 행 삭제
B2212_S03 = B2212_S03[(B2212_S03['요일']!='Fri')&(B2212_S03['요일']!='Sat')&(B2212_S03['요일']!='Sun')]

# %%
date = []
for i in range(0,len(pd.DataFrame(B2211_S03['사용일자']))):
  a = pd.DataFrame(B2211_S03['사용일자']).iat[i,0]
  date.append(days[datetime.date(int(str(a)[0:4]),int(str(a)[4:6]),int(str(a)[6:8])).weekday()])

# 요일 컬럼 집어넣기
B2211_S03.insert(0,'요일',date)

# 금, 토, 일 해당 행 삭제
B2211_S03 = B2211_S03[(B2211_S03['요일']!='Fri')&(B2211_S03['요일']!='Sat')&(B2211_S03['요일']!='Sun')]

# %%
date = []
for i in range(0,len(pd.DataFrame(B2210_S03['사용일자']))):
  a = pd.DataFrame(B2210_S03['사용일자']).iat[i,0]
  date.append(days[datetime.date(int(str(a)[0:4]),int(str(a)[4:6]),int(str(a)[6:8])).weekday()])

# 요일 컬럼 집어넣기
B2210_S03.insert(0,'요일',date)

# 금, 토, 일 해당 행 삭제
B2210_S03 = B2210_S03[(B2210_S03['요일']!='Fri')&(B2210_S03['요일']!='Sat')&(B2210_S03['요일']!='Sun')]

# %%
date = []
for i in range(0,len(pd.DataFrame(B2209_S03['사용일자']))):
  a = pd.DataFrame(B2209_S03['사용일자']).iat[i,0]
  date.append(days[datetime.date(int(str(a)[0:4]),int(str(a)[4:6]),int(str(a)[6:8])).weekday()])

# 요일 컬럼 집어넣기
B2209_S03.insert(0,'요일',date)

# 금, 토, 일 해당 행 삭제
B2209_S03 = B2209_S03[(B2209_S03['요일']!='Fri')&(B2209_S03['요일']!='Sat')&(B2209_S03['요일']!='Sun')]

# %%
date = []
for i in range(0,len(pd.DataFrame(B2208_S03['사용일자']))):
  a = pd.DataFrame(B2208_S03['사용일자']).iat[i,0]
  date.append(days[datetime.date(int(str(a)[0:4]),int(str(a)[4:6]),int(str(a)[6:8])).weekday()])

# 요일 컬럼 집어넣기
B2208_S03.insert(0,'요일',date)

# 금, 토, 일 해당 행 삭제
B2208_S03 = B2208_S03[(B2208_S03['요일']!='Fri')&(B2208_S03['요일']!='Sat')&(B2208_S03['요일']!='Sun')]

# %%
date = []
for i in range(0,len(pd.DataFrame(B2207_S03['사용일자']))):
  a = pd.DataFrame(B2207_S03['사용일자']).iat[i,0]
  date.append(days[datetime.date(int(str(a)[0:4]),int(str(a)[4:6]),int(str(a)[6:8])).weekday()])

# 요일 컬럼 집어넣기
B2207_S03.insert(0,'요일',date)

# 금, 토, 일 해당 행 삭제
B2207_S03 = B2207_S03[(B2207_S03['요일']!='Fri')&(B2207_S03['요일']!='Sat')&(B2207_S03['요일']!='Sun')]

# %%
Data_S03 = pd.concat([B2207_S03,B2208_S03,B2209_S03,B2210_S03,B2211_S03,B2212_S03])

# %%
plt.plot(list(Data_S03['승차총승객수']))
plt.title('2022.07.~12. Seodaemun03 Mon~Thu passengers(take-on)')
plt.show()

# %%
plt.plot(list(Data_S03['하차총승객수']))
plt.title('2022.07~12. Seodaemun03 Mon~Thu passengers(take-off)')
plt.show()

# %% [markdown]
# # **T-Test (유의수준 0.05)**

# %%
from scipy import stats

# %% [markdown]
# 타코벨 앞 정류장 - 서대문03 - 9월 vs. 11월 - 승차인원(월~목) 평균 차이가 유의미함

# %%
t_stat, p_value = stats.ttest_ind(B2209_S03['승차총승객수'], B2211_S03['승차총승객수'], equal_var=False, alternative="two-sided")
print("t-statistics : {}, p-value : {}".format(t_stat, p_value))
# Out:
# t-statistics : -2.6146800394274208, p-value : 0.013609959936879221

# %% [markdown]
# 타코벨 앞 정류장 - 서대문03 - 9월 vs. 11월 - 하차인원(월~목) 평균 차이가 유의미하지 않음

# %%
t_stat, p_value = stats.ttest_ind(B2209_S03['하차총승객수'], B2211_S03['하차총승객수'], equal_var=False, alternative="two-sided")
print("t-statistics : {}, p-value : {}".format(t_stat, p_value))
# Out:
# t-statistics : 1.47915416366082, p-value : 0.15499285778528804

# %% [markdown]
# 타코벨 앞 정류장 - 서대문04 - 9월 vs. 11월 - 승차인원(월~일)

# %%
t_stat, p_value = stats.ttest_ind(B2209_S04['승차총승객수'], B2211_S04['승차총승객수'], equal_var=False, alternative="two-sided")
print("t-statistics : {}, p-value : {}".format(t_stat, p_value))
# Out:
# t-statistics : -3.6713582190439706, p-value : 0.0008100305652806926

# %% [markdown]
# 타코벨 앞 정류장 - 서대문05 - 9월 vs. 11월 - 승차인원(월~일)

# %%
t_stat, p_value = stats.ttest_ind(B2209_S05['승차총승객수'], B2211_S05['승차총승객수'], equal_var=False, alternative="two-sided")
print("t-statistics : {}, p-value : {}".format(t_stat, p_value))
# Out:
# t-statistics : -3.1793575880412597, p-value : 0.00368468651934105

# %% [markdown]
# 타코벨 앞 정류장 - 7024 - 9월 vs. 11월 - 승차인원(월~일)

# %%
t_stat, p_value = stats.ttest_ind(B2209_7024['승차총승객수'], B2211_7024['승차총승객수'], equal_var=False, alternative="two-sided")
print("t-statistics : {}, p-value : {}".format(t_stat, p_value))
# Out:
# t-statistics : -3.995064581565382, p-value : 0.000395223453835064
